# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv")
df
# Out:
#   stocks data      Unnamed: 1 Unnamed: 2 Unnamed: 3      Unnamed: 4
# 0     tickers             eps    revenue      price          people
# 1       GOOGL           27.82         87        845      larry page
# 2         WMT            4.61        484         65              na
# 3        MSFT              -1         85         64      bill gates
# 4         RIL   not available         50       1023   mukesh ambani
# 5        TATA             5.6         -1         na      ratan tata

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv", skiprows = 1)
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv", header = 1)
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv", header = None, names =["tickers", "eps","revenue", "price", "people"])
df
# Out:
#   tickers             eps  revenue price          people
# 0   GOOGL           27.82       87   845      larry page
# 1     WMT            4.61      484    65              na
# 2    MSFT              -1       85    64      bill gates
# 3     RIL   not available       50  1023   mukesh ambani
# 4    TATA             5.6       -1    na      ratan tata

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv", header = None, nrows = 3)
df
# Out:
#          0      1         2       3            4
# 0  tickers    eps   revenue   price       people
# 1    GOOGL  27.82        87     845   larry page
# 2      WMT   4.61       484      65           na

# %%
df
# Out:
#          0      1         2       3            4
# 0  tickers    eps   revenue   price       people
# 1    GOOGL  27.82        87     845   larry page
# 2      WMT   4.61       484      65           na

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv")
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv", na_values = ["not available", "na"])
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df = pd.read_csv("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.csv", na_values = {
    'eps':["not available", "na"],
    'revenue':["not available", "na", -1],
    'price':["not available", "na"],
    'people':["not available", "na"]})
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df.to_csv("new.csv")

# %%
df.columns
# Out:
# Index(['tickers', ' eps', ' revenue', ' price', ' people'], dtype='object')

# %%
df.to_csv("new.csv", header= False)

# %%
df = pd.read_excel("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.xlsx")
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65              na
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
def c_p_c(cell):
    if cell == "n.a.":
        return 'sam walton'
    return cell

df = pd.read_excel("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.xlsx", converters = {
     'people': c_p_c
   })
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65            n.a.
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
def c_p_c(cell):
    if cell == "n.a.":
        return 'sam walton'
    return cell
def convert_eps_cell(cell):
    if cell == "not available":
        return None
    return cell
    

df = pd.read_excel("c:\\users\\Mannawar Hussain\\Desktop\\pandas\\stock_data.xlsx", converters = {
     'people': c_p_c,
    'eps': convert_eps_cell
    
   })
df
# Out:
#   tickers             eps   revenue  price          people
# 0   GOOGL           27.82        87    845      larry page
# 1     WMT            4.61       484     65            n.a.
# 2    MSFT              -1        85     64      bill gates
# 3     RIL   not available        50   1023   mukesh ambani
# 4    TATA             5.6        -1     na      ratan tata

# %%
df.to_excel("new.xlsx", sheet_name='stocks')

# %%
df.to_excel("new.xlsx", sheet_name='stocks', startrow =1, startcol=1)

# %%
df.to_excel("new.xlsx", sheet_name='stocks', index = False)

# %%
with pd.Excelwriter('stocks_weather.xlsx') as writer:
# Out:
#   File "<ipython-input-7-fe69242fcbca>", line 1
#     with pd.Excelwriter('stocks_weather.xlsx') as writer:
#                                                          ^
# SyntaxError: unexpected EOF while parsing
